# %% [markdown]
# # Use Case 2: Trans- PORT -ation Analysis
# - Q1 : Frequency for each type of service ( 6 different types )?
#     - Histogram | Bar chart
#     - Data required:
#         - Container.csv:
#             - Type of Service
#
#
# - Q2 : Weight Group proportional to Value for containers?
#     - Heat map? Scatter plot?
#     - Data required:
#         - tariff.csv:
#             - harmonized_value   [sum it all up]
#             - harmonized weight
#             - harmonized weight unit
#             - container_number
#
#
# - Q3 : TOTAL weight/value of cargo for each port?
#     - Histogram | Bar chart   | SQL
#     - Data required:
#         - Header.csv:
#             - weight (should be the weight of the order)...
#             - weight  unit
#             - port_of_unlading
#         - tariff.csv:
#             - harmonized_value [value per container]
#             - harmonized_weight ...(if not we need to get it from tariff )
#             - harmonized_weight unit
#
# - Q4 : Which ports were shipped from the most?
# - Q5 : Which ports received the most shipments?
#     - SQL COUNT() ? pie chart ?
#     - Data required:
#         - header.csv:
#             - (4) foreign_port_of_lading
#             - (5) port_of_unlading
#
# - Q6 : Frequency of Container Sizes used?
#     - Pie Chart
#     - Data required:
#         - Containers.csv:
#             - container_id
#             - container_length
#             - container_height
#             - contianer_width
#         - where am i getting container from?
#             - ATM can not say until data is cleaned
#
# - Q7 : How frequent were delays?
#     - SQL
#     - where days difference > 0  -> get the count for all BoL -> divide by total number of BOLS
#     - Data required:
#         - Headers.csv:
#             - estimated_arrival_date
#             - actual_arrival_date
#
# - Q8 : Which ports had the most delays?
#     - Data required:
#         - Headers.csv:
#             - port_of_unlading     (get ports)
#             - estimated_arrival_date
#             - actual_arrival_date
#
# - Q9 : Which months did these delays occur in?
#     - Data required:
#         -Headers.csv
#             - estimated_arrival_date    -> get the month for the arrival date increment if delay
#             - actual_arrival_date

# %% [markdown]
# # Use Case 1: Order Analysis
#
# - Q1 : Who are the most Frequent product "buyers"?
#     - View in SQL Query -> may be too many names to display on a chart
# - Q2 : Who are the most Frequent prduct "sellers?
#     - View in SQL query -> may be too many names to display on a chart
# - ~~Q3 : What type of products were purchased the most of?~~
#     - ~~View in SQL query -> group by products~~
# - ~~Q4 : Were specific products(tarif codes available) purchased more during certain times?~~
#     - ~~SQL query  ... scatterplot ? line plot? show a curve?~~
# - ~~Q5 : Were specific products being shipped out more from specific places?~~
#     - ~~bol_header -> 'place of receipt'~~
# - Q6 : Which hazmat class had places of lading different from place of receipt for shipping?
# - Q7 : Average weight of stated products shipped?
#     - SQL query | bar chart
#
# # Use Case 3: Shipment Analysis
# - Q1 : Farfetched... What is the seizure rate of products?  - require more data
# - Q2 : Which ports had the highest seizure rates?           - require more data
# - Q3 :
# - Q6 : Are the manifest quantity adding up to the total logged cargo per vessel?
# - Q7 :
